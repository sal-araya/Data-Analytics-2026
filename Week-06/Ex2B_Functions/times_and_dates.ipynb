# %%
## Lab 2. Working with datetime functions

# %%
import datetime

# %%
# Today

# %%
today = datetime.datetime.now()

# %%
print(today.strftime("Today is %A, %B %d, %Y"))
# Out:
# Today is Wednesday, May 13, 2026

# %%
# My birthday

# %%
birthday = datetime.date(2001, 3, 31)

# %%
print("My birthday is", birthday.strftime("%m/%d/%Y"))
# Out:
# My birthday is 03/31/2001

# %%
# Next 90 Days

# %%
ninety_d = today + datetime.timedelta(days=90)

# %%
print(ninety_d.strftime("90 days from today is %B %d, %Y"))
# Out:
# 90 days from today is August 11, 2026

# %%
# Time for Dinner

# %%
dinner_time = datetime.time(6, 30)

# %%
print(dinner_time.strftime("Let's meet for dinner at %I:%M %p"))
# Out:
# Let's meet for dinner at 06:30 AM
